# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv("datasets/verkehrszählungen_total_per_date.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date   Total    MR      PW  PW+   Lief  Lief+  \
# 0           0  01.01.2019  203861  2482  191182   62   6203     33
# 1           1  01.01.2020  204091  2464  189573   65   7834     42
# 2           2  01.01.2021  120411  1721  111778   26   4080     13
# 3           3  01.02.2019  430359  6465  374977  282  32252    383
# 4           4  01.02.2020  342801  5861  315812  336  13935    130
#
#    Lief+Aufl.    LW  LW+  Sattelzug   Bus  andere  Station Count  \
# 0          15   393   40        154  3165     132             32
# 1          22   537  104         98  3188     164             32
# 2           1   231   69        156  2312      24             32
# 3         273  7225  842       2819  4478     363             32
# 4          58  1455  283        664  4124     143             32
#
#    Number of Measurments
# 0                   1632
# 1                   1584
# 2                   1536
# 3                   1608
# 4                   1584

# %%
df.Date = df.Date.apply(lambda x: dt.datetime.strptime(x, "%d.%m.%Y"))

# %%
df.head()
# Out:
#    Unnamed: 0       Date   Total    MR      PW  PW+   Lief  Lief+  Lief+Aufl.  \
# 0           0 2019-01-01  203861  2482  191182   62   6203     33          15
# 1           1 2020-01-01  204091  2464  189573   65   7834     42          22
# 2           2 2021-01-01  120411  1721  111778   26   4080     13           1
# 3           3 2019-02-01  430359  6465  374977  282  32252    383         273
# 4           4 2020-02-01  342801  5861  315812  336  13935    130          58
#
#      LW  LW+  Sattelzug   Bus  andere  Station Count  Number of Measurments
# 0   393   40        154  3165     132             32                   1632
# 1   537  104         98  3188     164             32                   1584
# 2   231   69        156  2312      24             32                   1536
# 3  7225  842       2819  4478     363             32                   1608
# 4  1455  283        664  4124     143             32                   1584

# %%
df = df[(df.Date > "2020-10-01") & (df.Date < "2021-10-01")]

# %%
df.head()
# Out:
#     Unnamed: 0       Date   Total     MR      PW  PW+   Lief  Lief+  \
# 2            2 2021-01-01  120411   1721  111778   26   4080     13
# 5            5 2021-02-01  289054   5399  240289  183  28511    429
# 8            8 2021-03-01  306133   9766  252000  343  28363    451
# 11          11 2021-04-01  327455  13288  271541  404  27385    471
# 14          14 2021-05-01  210109   3143  194044  163   8855     61
#
#     Lief+Aufl.    LW  LW+  Sattelzug   Bus  andere  Station Count  \
# 2            1   231   69        156  2312      24             32
# 5          213  5923  843       3188  3883     193             32
# 8          197  6689  896       3354  3878     196             32
# 11         203  6048  986       3203  3690     236             32
# 14           7   809  129        281  2539      78             32
#
#     Number of Measurments
# 2                    1536
# 5                    1512
# 8                    1512
# 11                   1512
# ...

# %%
df = df.sort_values(by=["Date"])

# %%
df.head()
# Out:
#      Unnamed: 0       Date   Total     MR      PW  PW+   Lief  Lief+  \
# 62           62 2020-10-02  364368  11148  309760  417  29042    473
# 96           96 2020-10-03  282294   5521  258264  268  12454    115
# 130         130 2020-10-04  225985   6427  208039  183   7855     81
# 164         164 2020-10-05  337124   9668  284053  412  28388    462
# 198         198 2020-10-06  344361  10050  290411  325  28627    470
#
#      Lief+Aufl.    LW  LW+  Sattelzug   Bus  andere  Station Count  \
# 62          159  5996  791       2608  3770     204             31
# 96           31  1218  200        869  3235     119             31
# 130          15   494  107        153  2521     110             30
# 164         209  5963  880       3132  3731     226             30
# 198         209  6325  887       3191  3670     196             30
#
#      Number of Measurments
# 62                    1536
# 96                    1536
# 130                   1536
# 164                   1536
# ...

# %%
x = df.Date

# %%
y = df.Total

# %%
plt.figure(figsize=(10, 6), dpi=160)
plt.title("Total amount of vehicles counted in Basel\nFrom 2020-10-01 to 2021-10-01")
plt.xlabel("Date")
plt.ylabel("Vehicle count")
plt.plot(x, y)
plt.savefig("test.png")

# %%
df2 = pd.read_csv("datasets/luftklima_avg_by_date.csv")

# %%
df2.head()
# Out:
#    Unnamed: 0       Datum  Lufttemperatur  Regen in 1 h  Regen in 24 h  \
# 0           0  2020-04-02       15.740000           0.0            0.0
# 1           1  2020-04-16        6.633300           0.0            0.0
# 2           2  2020-04-18       13.270000           0.0            0.0
# 3           3  2020-04-20       19.842882           0.0            0.0
# 4           4  2020-04-21       15.240243           0.0            0.0
#
#    Regen in 48 h  Anzahl Stationen  Anzahl Messungen
# 0            0.6                 1                 1
# 1            0.0                 1                 1
# 2            0.0                 1                 1
# 3            0.0                 6                85
# 4            0.0                 6               144

# %%
df2 = df2[(df2.Datum > "2020-10-01") & (df2.Datum < "2021-10-01")]

# %%
df2.head()
# Out:
#      Unnamed: 0       Datum  Lufttemperatur  Regen in 1 h  Regen in 24 h  \
# 168         168  2020-10-02       12.879059      0.009287       2.148725
# 169         169  2020-10-03       11.412024      0.307931       7.009954
# 170         170  2020-10-04       14.321267      0.122338       7.159903
# 171         171  2020-10-05       11.129159      0.096110       3.147368
# 172         172  2020-10-06       13.252209      0.152686       2.417411
#
#      Regen in 48 h  Anzahl Stationen  Anzahl Messungen
# 168       2.957292               132              3058
# 169       9.116025               133              3064
# 170      14.257597               134              3080
# 171      10.375907               131              3059
# 172       5.564660               133              3090

# %%
luft = pd.read_csv("datasets/luftklima_reformatted.csv")

# %%
luft.head()
# Out:
#    Unnamed: 0 Station-ID                 Name                Zeitstempel  \
# 0           0   034003AA           Goetheanum  2020-04-02 08:39:53+02:00
# 1           1   03400395   Hegenheimermattweg  2020-04-16 04:49:29+02:00
# 2           2   0340997E        Laufenstrasse  2020-04-18 05:41:57+02:00
# 3           3   0340018F  Areal Wolf (Mast 7)  2020-04-20 11:49:23+02:00
# 4           4   034001AD  Areal Wolf (Mast 6)  2020-04-20 11:50:09+02:00
#
#         Datum  Stunde  Minute                  Koordinaten  Breitengrad  \
# 0  2020-04-02       8      39             47.53934,7.60146     47.53934
# 1  2020-04-16       4      49             47.57551,7.58309     47.57551
# 2  2020-04-18       5      41  47.5935204569,7.59419060652     47.59352
# 3  2020-04-20      11      49             47.54245,7.61357     47.54245
# 4  2020-04-20      11      50             47.54431,7.60302     47.54431
#
#    Längengrad  Lufttemperatur  Regen in 1 h  Regen in 24 h  Regen in 48 h
# ...

# %%
luft = luft[(luft.Datum > "2020-10-01") & (luft.Datum < "2021-10-01")]

# %%
luft.head()
# Out:
#         Unnamed: 0 Station-ID                Name                Zeitstempel  \
# 401390      401390   0320024A          St. Johann  2020-10-02 00:00:01+02:00
# 401391      401391   034099A8         Brünnlirain  2020-10-02 00:00:15+02:00
# 401392      401392   0340A016  Am Wasserkraftwerk  2020-10-02 00:00:19+02:00
# 401393      401393   03409996    Dorenbachviadukt  2020-10-02 00:00:23+02:00
# 401394      401394   034099A2      Hangelimattweg  2020-10-02 00:00:28+02:00
#
#              Datum  Stunde  Minute              Koordinaten  Breitengrad  \
# 401390  2020-10-02       0       0         47.56597,7.58201    47.565970
# 401391  2020-10-02       0       0         47.59263,7.65389    47.592630
# 401392  2020-10-02       0       0  47.54116176,7.705843832    47.541162
# 401393  2020-10-02       0       0         47.54391,7.58117    47.543910
# 401394  2020-10-02       0       0         47.45859,7.57834    47.458590
#
# ...

# %%
luft.Datum = luft.Datum.apply(lambda x: dt.datetime.strptime(x, "%Y-%m-%d"))

# %%
df2.Datum = df2.Datum.apply(lambda x: dt.datetime.strptime(x, "%Y-%m-%d"))

# %%
tmax = luft.groupby(by="Datum").max().reset_index()

# %%
tmin = luft.groupby(by="Datum").min().reset_index()

# %%
x1 = df2.Datum
y1 = df2.Lufttemperatur
x2 = tmax.Datum
y2 = tmax.Lufttemperatur
x3 = tmin.Datum
y3 = tmin.Lufttemperatur

# %%
plt.figure(figsize=(10, 8), dpi=160)
plt.plot(x1, y1, label="average temperature", color="forestgreen")
plt.plot(x2, y2, label="maximum temperature", color="firebrick")
plt.plot(x3, y3, label="minimum temperature", color="mediumblue")
plt.legend()
plt.xlabel("Date")
plt.ylabel("°C")
plt.title("Comparison of average, maximum and minimum Temperature in Basel")
plt.savefig("minmax.png")

# %%
delta = y2 - y3

# %%
plt.figure(figsize=(10, 8), dpi=160)
plt.plot(x2, delta)
